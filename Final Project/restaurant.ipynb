# %%
import pandas as pd
# Load data
data_path = "./dataset/restaurant/"
df_train = pd.read_csv(data_path + "train.csv")
df_test = pd.read_csv(data_path + "test.csv")
# keep attributes.Ambience, attributes.AgesAllowed, attributes.GoodForDancing, attributes.RestaurantsReservations, attributes.RestaurantsPriceRange2, stars, review, attributes.NoiseLevel, id, name, label for training dataset
columns_to_keep = [
        'name', 
        'review',
        'label'
    ]
df_train = df_train[columns_to_keep]
df_test = df_test[columns_to_keep[:-1]]

import string
import re

# remove sepcial characters
def remove_special_characters(text):
    # remove change line
    text = text.replace('\\n', ' ')
    # Replace special characters with a space
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    return text

df_train['review'] = df_train['review'].apply(remove_special_characters)
df_test['review'] = df_test['review'].apply(remove_special_characters)

print("text after removing special characters:", df_train['review'][0])

# remove urls and html tags
def remove_urls(text):
    text = re.sub(r'http\S+', ' ', text)
    text = re.sub(r'<.*?>', ' ', text)
    return text

df_train['review'] = df_train['review'].apply(remove_urls)
df_test['review'] = df_test['review'].apply(remove_urls)

print("text after removing urls and html tags:", df_train['review'][0])

# remove extra whitespaces
def remove_extra_whitespaces(text):
    text = re.sub(' +', ' ', text)
    return text

df_train['review'] = df_train['review'].apply(remove_extra_whitespaces)
df_test['review'] = df_test['review'].apply(remove_extra_whitespaces)

print("text after removing extra whitespaces:", df_train['review'][0])
# Out:
# text after removing special characters: So  we stopped here on our way to the Side Quest  which is just up the street    We did not know what to expect  but came on a 3  taco night     I m so glad we did    Mostly  the Rush Inn is a bar ish place  but there s plenty of back and side seating at booths all through  The place has a dark  rich wood tone  and the patrons were decent folks   The tacos were EXCEPTIONAL  and their selection is quite good  with all sorts of stuff I intend to try as soon as possible  I think this place would make a nice casual dinner lunch stop  and if you need to get beverage  the barkeep and wait staff will keep em coming    So  for a quick tasty bite  don t walk slow  RUSH IN TO THE RUSH INN  My boyfriend and I heard about this little place near Rush Inn that offered board games and poutine on Friday  When we arrived  they didn t have food because the chef didn t show up     so we ventured to this place a block down  Great vibe inside  A typical bar scene  but had great booze selections and a decently large menu to choose from  I ordered the grilled chicken wrap  smothered in buffalo  and my boyfriend ordered the soft crab sandwich   BOTH WERE DELICIOUS   We are both huge foodies  and consider ourselves pretty in tune with all the good eats in or around Cleveland  and this was a treasure of a find    We will definitely be going back  Whoever said this is your typical bar food is nuts   what bar has a stir fried veggie dish  home made mashed potatoes  home made soups  flat bread pizzas  peroghes and fresh veggies     The place is outstanding   The menu is huge and varied  something for everyone for sure   6 00 burger night on Wednesdays   Not to mention  the staff is very accommodating and friendly  Plus the music they play is great   A great local bar that will serve you really good food    not just bar food  but REALLY good food  Continuous consistency  party of 12 adults kids  Best wings in Lakewood  this visit tasty bbq and zesty teriyaki  Also generous sides of potato skins and mozzarella sticks  Others in party raved about the burgers  potato pancakes and  really good  fries  Timely service for a busy Friday night  Good noise level so kids are never an issue whether with you or at another booth  Friendly staff this night and always  Seafood and steak dishes always satisfying from previous visits  not what you  d expect from a  bar food  spot  Keep it up  Second time at Rush Inn and we had great food and service both times  The atmoshere is what you would expect  nothing fancy but clean and comfortable  The fish sandwich was one of the best I ve ever had  So well cooked with a unique tartar sauce and super fresh bun  The food came out really fast too and our waitress checked on us often but not in the annoying way
# text after removing urls and html tags: So  we stopped here on our way to the Side Quest  which is just up the street    We did not know what to expect  but came on a 3  taco night     I m so glad we did    Mostly  the Rush Inn is a bar ish place  but there s plenty of back and side seating at booths all through  The place has a dark  rich wood tone  and the patrons were decent folks   The tacos were EXCEPTIONAL  and their selection is quite good  with all sorts of stuff I intend to try as soon as possible  I think this place would make a nice casual dinner lunch stop  and if you need to get beverage  the barkeep and wait staff will keep em coming    So  for a quick tasty bite  don t walk slow  RUSH IN TO THE RUSH INN  My boyfriend and I heard about this little place near Rush Inn that offered board games and poutine on Friday  When we arrived  they didn t have food because the chef didn t show up     so we ventured to this place a block down  Great vibe inside  A typical bar scene  but had great booze selections and a decently large menu to choose from  I ordered the grilled chicken wrap  smothered in buffalo  and my boyfriend ordered the soft crab sandwich   BOTH WERE DELICIOUS   We are both huge foodies  and consider ourselves pretty in tune with all the good eats in or around Cleveland  and this was a treasure of a find    We will definitely be going back  Whoever said this is your typical bar food is nuts   what bar has a stir fried veggie dish  home made mashed potatoes  home made soups  flat bread pizzas  peroghes and fresh veggies     The place is outstanding   The menu is huge and varied  something for everyone for sure   6 00 burger night on Wednesdays   Not to mention  the staff is very accommodating and friendly  Plus the music they play is great   A great local bar that will serve you really good food    not just bar food  but REALLY good food  Continuous consistency  party of 12 adults kids  Best wings in Lakewood  this visit tasty bbq and zesty teriyaki  Also generous sides of potato skins and mozzarella sticks  Others in party raved about the burgers  potato pancakes and  really good  fries  Timely service for a busy Friday night  Good noise level so kids are never an issue whether with you or at another booth  Friendly staff this night and always  Seafood and steak dishes always satisfying from previous visits  not what you  d expect from a  bar food  spot  Keep it up  Second time at Rush Inn and we had great food and service both times  The atmoshere is what you would expect  nothing fancy but clean and comfortable  The fish sandwich was one of the best I ve ever had  So well cooked with a unique tartar sauce and super fresh bun  The food came out really fast too and our waitress checked on us often but not in the annoying way
# text after removing extra whitespaces: So we stopped here on our way to the Side Quest which is just up the street We did not know what to expect but came on a 3 taco night I m so glad we did Mostly the Rush Inn is a bar ish place but there s plenty of back and side seating at booths all through The place has a dark rich wood tone and the patrons were decent folks The tacos were EXCEPTIONAL and their selection is quite good with all sorts of stuff I intend to try as soon as possible I think this place would make a nice casual dinner lunch stop and if you need to get beverage the barkeep and wait staff will keep em coming So for a quick tasty bite don t walk slow RUSH IN TO THE RUSH INN My boyfriend and I heard about this little place near Rush Inn that offered board games and poutine on Friday When we arrived they didn t have food because the chef didn t show up so we ventured to this place a block down Great vibe inside A typical bar scene but had great booze selections and a decently large menu to choose from I ordered the grilled chicken wrap smothered in buffalo and my boyfriend ordered the soft crab sandwich BOTH WERE DELICIOUS We are both huge foodies and consider ourselves pretty in tune with all the good eats in or around Cleveland and this was a treasure of a find We will definitely be going back Whoever said this is your typical bar food is nuts what bar has a stir fried veggie dish home made mashed potatoes home made soups flat bread pizzas peroghes and fresh veggies The place is outstanding The menu is huge and varied something for everyone for sure 6 00 burger night on Wednesdays Not to mention the staff is very accommodating and friendly Plus the music they play is great A great local bar that will serve you really good food not just bar food but REALLY good food Continuous consistency party of 12 adults kids Best wings in Lakewood this visit tasty bbq and zesty teriyaki Also generous sides of potato skins and mozzarella sticks Others in party raved about the burgers potato pancakes and really good fries Timely service for a busy Friday night Good noise level so kids are never an issue whether with you or at another booth Friendly staff this night and always Seafood and steak dishes always satisfying from previous visits not what you d expect from a bar food spot Keep it up Second time at Rush Inn and we had great food and service both times The atmoshere is what you would expect nothing fancy but clean and comfortable The fish sandwich was one of the best I ve ever had So well cooked with a unique tartar sauce and super fresh bun The food came out really fast too and our waitress checked on us often but not in the annoying way

# %%
# print labels
print("labels:", df_train['label'].unique())
# Out:
# labels: ['american (traditional)' 'american (new)' 'mexican' 'chinese'
#  'mediterranean' 'italian' 'thai' 'asian fusion' 'canadian (new)'
#  'japanese']

# %% [markdown]
# # Various Sample Prompt

# %%
import ollama
from sklearn.metrics import accuracy_score
def chat_with_context(history):
    response = ollama.chat(model='llama3', messages=history)
    return response['message']['content']
chat_history = []

num_samples = 5
# Updated Task Description for Restaurant Type Prediction
task_description = "We need to predict the type restaurant based on its name and one customer review. The categories are 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'."

generate_samples_request = (
    f"As an advanced language model you should create {num_samples} samples for the task outlined below.\n"
    "Generate samples that are likely to be correctly classified into one of the specified categories and samples that might be misclassified according to the task instructions.\n\n"
    f"### Task Description:\n{task_description}\n\n"
    "### Requirements for Samples:\n"
    "1. **Unique Challenges:** Each sample must present a unique and intricate challenge that tests various aspects of the task.\n"
    "2. **Complexity and Ambiguity:** The complexity of the samples should be such that applying the given task instructions might lead to incorrect or incomplete results for some samples. Introduce subtle ambiguities or edge cases to test the robustness of the classification.\n"
    "3. **Diverse Scenarios:** The samples should cover a wide range of scenarios within the scope of the task, avoiding repetition and ensuring diversity in the challenges presented.\n"
    "4. **Realism and Pertinence:** Ensure that the samples, while challenging, remain realistic and relevant to the task's context. They should reflect real-world applications and potential use cases.\n"
    "5. **Balanced Difficulty:** Include a balanced mix of straightforward, moderately challenging, and highly complex samples to facilitate comprehensive analysis.\n"
    "6. **Contextual Detail:** Provide sufficient contextual detail in each sample to support accurate classification, while also including elements that might introduce classification challenges.\n"
    "7. **Potential Misclassification:** Design some samples with elements that are likely to lead to misclassification, to evaluate the model's ability to handle such cases.\n\n"
    "Generate the samples keeping these requirements in mind.\n###"
)

chat_history.append({'role': 'user', 'content': task_description})
chat_history.append({'role': 'user', 'content': generate_samples_request})

samples_response = chat_with_context(chat_history)
chat_history.append({'role': 'assistant', 'content': samples_response})
print("Generated Samples:")
print(samples_response)

# Analyze Samples with Chain of Thought Request
analyze_samples_request = (
    f"Based on the provided samples: {samples_response}\n"
    "Please think step by step and derive general principles for classifying restaurants into the specified categories: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
    "Focus on creating broad, example-agnostic guidelines that can be applied universally to classify any restaurant based on its name and customer reviews. Conclude your analysis with clear, concise bullet points outlining:\n"
    "- The key indicators or characteristics that typically define each category.\n"
    "- Common pitfalls that might lead to misclassifications and strategies for avoiding these errors.\n"
    "- Criteria or rules under which circumstances each label should be predicted.\n"
    "These principles should help in accurately predicting the cuisine type of a restaurant without relying on specific examples."
)

chat_history.append({'role': 'user', 'content': analyze_samples_request})

# Retrieve and print the analysis from the language model
analysis_response = chat_with_context(chat_history)
chat_history.append({'role': 'assistant', 'content': analysis_response})
print("Analysis of Restaurant Classification Guidelines:")
print(analysis_response)

# Generate Optimized Prompt
generate_prompt_request = (
    f"Based on the following analysis: {analysis_response}\nGenerate an optimized prompt for predicting "
    "the type of restaurant. Ensure the model responds only with one of the specified categories: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n\n"
    "### Requirements for Optimized Prompt:\n"
    "1. The prompt must include a clear description of the task and the labels.\n"
    "2. It should provide a comprehensive criteria for classifying restaurants as one of the restaurant types: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese' based on the name and customer review.\b"
    "3. The prompt must ensure that the model responds strictly with one of 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\b"
    "4. The prompt should help the model avoid common pitfalls and misclassifications identified during the analysis.\n"
    "5. Ensure the language is unambiguous and tailored to maximize the model's prediction accuracy.\n"
    "6. Encourage the model to think step by step.\n"
    "Respond with no other explanation but only the content of the prompt that is ready for the model to predict\n"
    "Prompt:"
)

chat_history.append({'role': 'user', 'content': generate_prompt_request})

optimized_prompt_response = chat_with_context(chat_history)
chat_history.append({'role': 'assistant', 'content': optimized_prompt_response})
print("Optimized Prompt:")
print(optimized_prompt_response)


# Function to predict the cuisine type of a given restaurant
def get_prediction(restaurant_name, customer_review):
    prompt = (
        "Follow the guidelines of the prompt:\n"
        f"{optimized_prompt_response}\n\n"
        f"Restaurant Name: {restaurant_name}\n"
        f"Customer Review: {customer_review}\n"
        "### Requirements:\n"
        "1. Respond with only the restaurant type: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
        "2. Do not provide any additional text or explanation.\n"
        "Respond with only the cuisine name:"
    )
    response = ollama.generate(model='llama3', prompt=prompt)

    prediction = response['response'].strip().lower().replace("**", "").replace("'", "").replace('"', '')
    # if prediction not in ['American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese']:
    #     prediction = "Invalid Prediction"
    return prediction

predictions = []

for i, row in df_train.iterrows():
    if i == 10000:
        break
    if i % 1000 == 0:
        print(f"Processed {i+1} samples")
    restaurant_name = row['name']
    customer_review = row['review']
    prediction = get_prediction(restaurant_name, customer_review)
    predictions.append(prediction)
    # print(f"Predicted Restaurant Type: {prediction}\n")
    # print(f"Actual Restaurant Type: {row['label']}\n")

accuracy = accuracy_score(df_train['label'][:len(predictions)], predictions)
print(f"Accuracy: {accuracy}")
# Out:
# Generated Samples:
# Here are five samples that meet the requirements:
#
# **Sample 1:**
# Restaurant Name: Fusion Station
# Customer Review: "The menu is a mix of Korean BBQ and American comfort food. I had the bulgogi beef sliders with kimchi slaw, and it was amazing! The atmosphere is modern and lively."
#
# **Challenge:** This sample combines Asian fusion elements (Korean BBQ) with American comfort food, making it challenging to categorize based solely on the name.
#
# **Sample 2:**
# Restaurant Name: Bella Vita
# Customer Review: "This cozy Italian place serves up authentic pasta dishes like nonna used to make. The fettuccine Alfredo is creamy and rich."
#
# **Challenge:** The name suggests Mediterranean or Italian cuisine, but the customer review focuses specifically on traditional Italian food, making it unclear which category best fits.
#
# **Sample 3:**
# Restaurant Name: Tamarindo
# Customer Review: "I tried the chiles rellenos with roasted vegetables, and it was love at first bite. The patio has a great view of the city."
#
# **Challenge:** The name suggests Mexican cuisine, but the customer review mentions roasted vegetables, which could be a hint towards a fusion or Mediterranean-inspired dish.
#
# **Sample 4:**
# Restaurant Name: Jade Garden
# Customer Review: "The Szechuan chicken was spicy and savory, served with steamed broccoli. The decor is elegant and modern."
#
# **Challenge:** The name suggests Chinese cuisine, but the customer review mentions Szechuan flavors and an elegant atmosphere, which could be a hint towards higher-end or contemporary Asian fusion.
#
# **Sample 5:**
# Restaurant Name: Bannock's
# Customer Review: "This Canadian-inspired cafe serves up poutine with Montreal-style smoked meat. The cozy atmosphere is perfect for a cold winter day."
#
# **Challenge:** The name suggests Canadian cuisine, but the customer review focuses specifically on a popular dish from Quebec (Montreal-style smoked meat), making it unclear whether this restaurant fits into the 'Canadian (New)' category or another category entirely.
#
# These samples aim to present unique and intricate challenges that require careful consideration of both the restaurant name and the customer review to make an accurate classification.
# Analysis of Restaurant Classification Guidelines:
# After analyzing the samples, I've derived general principles for classifying restaurants into the specified categories. Here are the key findings:
#
# **Key Indicators/Characteristics:**
#
# * **American (Traditional):**
# 	+ Name containing "American" or "Classic"
# 	+ Menu featuring traditional American dishes like burgers, mac 'n cheese, and comfort food
# 	+ Customer reviews mentioning classic American flavors or nostalgic atmosphere
# * **American (New):**
# 	+ Name suggesting modern twists or innovation (e.g., "Fusion," "Modern," "Fresh")
# 	+ Menu showcasing contemporary American cuisine with unique flavor combinations
# 	+ Customer reviews highlighting creative dishes, bold flavors, and trendy atmosphere
# * **Mexican:**
# 	+ Name containing "Mex" or "Taco"
# 	+ Menu featuring traditional Mexican dishes like tacos, burritos, and quesadillas
# 	+ Customer reviews mentioning authentic Mexican flavors, vibrant colors, and lively atmosphere
# * **Chinese:**
# 	+ Name suggesting Chinese cuisine (e.g., "Jade," "Wok")
# 	+ Menu featuring traditional Chinese dishes like stir-fries, noodles, and dim sum
# 	+ Customer reviews highlighting wok-fried foods, delicate sauces, and ornate decor
# * **Mediterranean:**
# 	+ Name containing "Med" or "Olive"
# 	+ Menu featuring Mediterranean-inspired dishes with olive oil, lemon, and herbs
# 	+ Customer reviews mentioning fresh flavors, rustic atmosphere, and warm hospitality
# * **Italian:**
# 	+ Name suggesting Italian cuisine (e.g., "Bella Vita," "Pasta")
# 	+ Menu featuring traditional Italian dishes like pasta, pizza, and risotto
# 	+ Customer reviews highlighting rich flavors, cozy atmosphere, and classic Italian charm
# * **Thai:**
# 	+ Name containing "Thai" or "Bangkok"
# 	+ Menu featuring authentic Thai dishes like pad thai, tom yum soup, and green curry
# 	+ Customer reviews mentioning spicy flavors, vibrant colors, and bustling atmosphere
# * **Asian Fusion:**
# 	+ Name suggesting fusion cuisine (e.g., "Fusion Station")
# 	+ Menu blending Asian flavors with Western or international twists
# 	+ Customer reviews highlighting creative combinations of East meets West
# * **Canadian (New):**
# 	+ Name suggesting modern Canadian cuisine (e.g., "Bannock's")
# 	+ Menu featuring contemporary Canadian dishes with fresh, local ingredients
# 	+ Customer reviews mentioning innovative flavors, cozy atmosphere, and pride in Canadian heritage
# * **Japanese:**
# 	+ Name containing "Japan" or "Sushi"
# 	+ Menu featuring traditional Japanese dishes like sushi, ramen, and tempura
# 	+ Customer reviews highlighting delicate flavors, serene atmosphere, and respect for Japanese culture
#
# **Common Pitfalls and Strategies:**
#
# * Be cautious of names that seem generic (e.g., "Food" or "Grill") without considering the menu or customer reviews.
# * Avoid misclassifying based on a single characteristic; consider multiple indicators and patterns.
# * Don't rely solely on customer reviews; analyze the name, menu, and overall atmosphere to make an informed decision.
#
# **Criteria/Rules:**
#
# 1. **Name-based classification:** If the name strongly suggests a specific cuisine (e.g., "Tamarindo" for Mexican), prioritize that classification.
# 2. **Menu-driven analysis:** If the menu is diverse or features unique flavor combinations, consider Asian Fusion or American (New) categories.
# 3. **Customer review insights:** Pay attention to customer reviews highlighting cultural authenticity, traditional flavors, or modern twists; these can influence the final classification.
# 4. **Atmosphere and decor:** Analyze the restaurant's atmosphere and decor to further support or contradict the initial classification.
#
# By considering these key indicators, common pitfalls, and criteria, you'll be better equipped to accurately predict the type of cuisine a restaurant serves based on its name and customer reviews.
# Optimized Prompt:
# Here is the optimized prompt:
#
# Classify a restaurant based on its name and customer reviews into one of the following categories: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', or 'Japanese'.
#
# Consider the following criteria:
#
# * Name-based classification: If the name suggests a specific cuisine, prioritize that category. For example, "Tamarindo" for Mexican.
# * Menu-driven analysis: Analyze the menu for traditional dishes, unique flavor combinations, and cultural authenticity to inform your classification.
# * Customer review insights: Pay attention to customer reviews highlighting cultural authenticity, traditional flavors, or modern twists to guide your decision.
# * Atmosphere and decor: Consider the restaurant's atmosphere and decor to further support or contradict your initial classification.
#
# Avoid common pitfalls by being cautious of generic names and considering multiple indicators before making a decision. Respond with only one category from the list above: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', or 'Japanese'.
# Processed 1 samples
# Processed 1001 samples
# Processed 2001 samples
# Processed 3001 samples
# Processed 4001 samples
# Processed 5001 samples
# Processed 6001 samples
# Processed 7001 samples
# Processed 8001 samples
# Processed 9001 samples
# Accuracy: 0.767

# %% [markdown]
# # Basic Prompt

# %%
def get_prediction(restaurant_name, customer_review):
    prompt = (
        "Predict the type of restaurant based on the given restaurant name and customer review.\n"
        f"Restaurant Name: {restaurant_name}\n"
        f"Customer Review: {customer_review}\n"
        "### Requirements:\n"
        "1. Respond with only the restaurant type: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
        "2. Do not provide any additional text or explanation.\n"
        "Respond with only the cuisine name:"
    )
    response = ollama.generate(model='llama3', prompt=prompt)

    prediction = response['response'].strip().lower()
    # if prediction not in ['American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese']:
    #     prediction = "Invalid Prediction"
    return prediction

predictions = []

for i, row in df_train.iterrows():
    if i == 10000:
        break
    if i % 100 == 0:
        print(f"Processed {i+1} samples")
    restaurant_name = row['name']
    customer_review = row['review']
    prediction = get_prediction(restaurant_name, customer_review)
    predictions.append(prediction)
    # print(f"Predicted Restaurant Type: {prediction}\n")
    # print(f"Actual Restaurant Type: {row['label']}\n")

accuracy = accuracy_score(df_train['label'][:len(predictions)], predictions)
print(f"Accuracy on the first 100 samples: {accuracy}")
# Out:
# Processed 1 samples
# Processed 101 samples
# Processed 201 samples
# Processed 301 samples
# Processed 401 samples
# Processed 501 samples
# Processed 601 samples
# Processed 701 samples
# Processed 801 samples
# Processed 901 samples
# Processed 1001 samples
# Processed 1101 samples
# Processed 1201 samples
# Processed 1301 samples
# Processed 1401 samples
# Processed 1501 samples
# Processed 1601 samples
# Processed 1701 samples
# Processed 1801 samples
# Processed 1901 samples
# Processed 2001 samples
# Processed 2101 samples
# Processed 2201 samples
# Processed 2301 samples
# Processed 2401 samples
# Processed 2501 samples
# Processed 2601 samples
# Processed 2701 samples
# Processed 2801 samples
# Processed 2901 samples
# Processed 3001 samples
# Processed 3101 samples
# Processed 3201 samples
# Processed 3301 samples
# Processed 3401 samples
# Processed 3501 samples
# Processed 3601 samples
# Processed 3701 samples
# Processed 3801 samples
# Processed 3901 samples
# Processed 4001 samples
# Processed 4101 samples
# Processed 4201 samples
# Processed 4301 samples
# Processed 4401 samples
# Processed 4501 samples
# Processed 4601 samples
# Processed 4701 samples
# Processed 4801 samples
# Processed 4901 samples
# Processed 5001 samples
# Processed 5101 samples
# Processed 5201 samples
# Processed 5301 samples
# Processed 5401 samples
# Processed 5501 samples
# Processed 5601 samples
# Processed 5701 samples
# Processed 5801 samples
# Processed 5901 samples
# Processed 6001 samples
# Processed 6101 samples
# Processed 6201 samples
# Processed 6301 samples
# Processed 6401 samples
# Processed 6501 samples
# Processed 6601 samples
# Processed 6701 samples
# Processed 6801 samples
# Processed 6901 samples
# Processed 7001 samples
# Processed 7101 samples
# Processed 7201 samples
# Processed 7301 samples
# Processed 7401 samples
# Processed 7501 samples
# Processed 7601 samples
# Processed 7701 samples
# Processed 7801 samples
# Processed 7901 samples
# Processed 8001 samples
# Processed 8101 samples
# Processed 8201 samples
# Processed 8301 samples
# Processed 8401 samples
# Processed 8501 samples
# Processed 8601 samples
# Processed 8701 samples
# Processed 8801 samples
# Processed 8901 samples
# Processed 9001 samples
# Processed 9101 samples
# Processed 9201 samples
# Processed 9301 samples
# Processed 9401 samples
# Processed 9501 samples
# Processed 9601 samples
# Processed 9701 samples
# Processed 9801 samples
# Processed 9901 samples
# Accuracy on the first 100 samples: 0.7416

# %% [markdown]
# # zero shot COT prompt

# %%
def get_prediction(restaurant_name, customer_review):
    prompt = (
        "Predict the type of restaurant based on the given restaurant name and customer review.\n"
        "Let's think step by step:\n"
        f"Restaurant Name: {restaurant_name}\n"
        f"Customer Review: {customer_review}\n"
        "### Requirements:\n"
        "1. Respond with only the restaurant type: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
        "2. Do not provide any additional text or explanation.\n"
        "Respond with only the cuisine name:"
    )
    response = ollama.generate(model='llama3', prompt=prompt)

    prediction = response['response'].strip().lower()
    # if prediction not in ['American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese']:
    #     prediction = "Invalid Prediction"
    return prediction

predictions = []

for i, row in df_train.iterrows():
    if i == 10000:
        break
    if i % 100 == 0:
        print(f"Processed {i+1} samples")
    restaurant_name = row['name']
    customer_review = row['review']
    prediction = get_prediction(restaurant_name, customer_review)
    predictions.append(prediction)
    # print(f"Predicted Restaurant Type: {prediction}\n")
    # print(f"Actual Restaurant Type: {row['label']}\n")

accuracy = accuracy_score(df_train['label'][:len(predictions)], predictions)
print(f"Accuracy on the first 100 samples: {accuracy}")
# Out:
# Processed 1 samples
# Processed 101 samples
# Processed 201 samples
# Processed 301 samples
# Processed 401 samples
# Processed 501 samples
# Processed 601 samples
# Processed 701 samples
# Processed 801 samples
# Processed 901 samples
# Processed 1001 samples
# Processed 1101 samples
# Processed 1201 samples
# Processed 1301 samples
# Processed 1401 samples
# Processed 1501 samples
# Processed 1601 samples
# Processed 1701 samples
# Processed 1801 samples
# Processed 1901 samples
# Processed 2001 samples
# Processed 2101 samples
# Processed 2201 samples
# Processed 2301 samples
# Processed 2401 samples
# Processed 2501 samples
# Processed 2601 samples
# Processed 2701 samples
# Processed 2801 samples
# Processed 2901 samples
# Processed 3001 samples
# Processed 3101 samples
# Processed 3201 samples
# Processed 3301 samples
# Processed 3401 samples
# Processed 3501 samples
# Processed 3601 samples
# Processed 3701 samples
# Processed 3801 samples
# Processed 3901 samples
# Processed 4001 samples
# Processed 4101 samples
# Processed 4201 samples
# Processed 4301 samples
# Processed 4401 samples
# Processed 4501 samples
# Processed 4601 samples
# Processed 4701 samples
# Processed 4801 samples
# Processed 4901 samples
# Processed 5001 samples
# Processed 5101 samples
# Processed 5201 samples
# Processed 5301 samples
# Processed 5401 samples
# Processed 5501 samples
# Processed 5601 samples
# Processed 5701 samples
# Processed 5801 samples
# Processed 5901 samples
# Processed 6001 samples
# Processed 6101 samples
# Processed 6201 samples
# Processed 6301 samples
# Processed 6401 samples
# Processed 6501 samples
# Processed 6601 samples
# Processed 6701 samples
# Processed 6801 samples
# Processed 6901 samples
# Processed 7001 samples
# Processed 7101 samples
# Processed 7201 samples
# Processed 7301 samples
# Processed 7401 samples
# Processed 7501 samples
# Processed 7601 samples
# Processed 7701 samples
# Processed 7801 samples
# Processed 7901 samples
# Processed 8001 samples
# Processed 8101 samples
# Processed 8201 samples
# Processed 8301 samples
# Processed 8401 samples
# Processed 8501 samples
# Processed 8601 samples
# Processed 8701 samples
# Processed 8801 samples
# Processed 8901 samples
# Processed 9001 samples
# Processed 9101 samples
# Processed 9201 samples
# Processed 9301 samples
# Processed 9401 samples
# Processed 9501 samples
# Processed 9601 samples
# Processed 9701 samples
# Processed 9801 samples
# Processed 9901 samples
# Accuracy on the first 100 samples: 0.7479

# %% [markdown]
# # few shot prompting

# %%
# use the first three samples to generate the few-shot text
few_shot_texts = df_train['review'][:3]
few_shot_labels = df_train['label'][:3]
def get_prediction(restaurant_name, customer_review):
    prompt = (
        "Here are three samples in the dataset to help you predict the type of restaurant based on the given restaurant name and customer review.\n"
        f"sample 1: {few_shot_texts[0]}. Label: {few_shot_labels[0]}\n"
        f"sample 2: {few_shot_texts[1]}. Label: {few_shot_labels[1]}\n"
        f"sample 3: {few_shot_texts[2]}. Label: {few_shot_labels[2]}\n"
        "Predict the type of restaurant based on the given restaurant name and customer review.\n"
        f"Restaurant Name: {restaurant_name}\n"
        f"Customer Review: {customer_review}\n"
        "### Requirements:\n"
        "1. Respond with only the restaurant type: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
        "2. Do not provide any additional text or explanation.\n"
        "Respond with only the cuisine name:"
    )
    response = ollama.generate(model='llama3', prompt=prompt)

    prediction = response['response'].strip().lower()
    # if prediction not in ['American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese']:
    #     prediction = "Invalid Prediction"
    return prediction

predictions = []

for i, row in df_train.iterrows():
    if i == 10000:
        break
    if i % 100 == 0:
        print(f"Processed {i+1} samples")
    restaurant_name = row['name']
    customer_review = row['review']
    prediction = get_prediction(restaurant_name, customer_review)
    predictions.append(prediction)
    # print(f"Predicted Restaurant Type: {prediction}\n")
    # print(f"Actual Restaurant Type: {row['label']}\n")

accuracy = accuracy_score(df_train['label'][:len(predictions)], predictions)
print(f"Accuracy on the first 100 samples: {accuracy}")
# Out:
# Processed 1 samples
# Processed 101 samples
# Processed 201 samples
# Processed 301 samples
# Processed 401 samples
# Processed 501 samples
# Processed 601 samples
# Processed 701 samples
# Processed 801 samples
# Processed 901 samples
# Processed 1001 samples
# Processed 1101 samples
# Processed 1201 samples
# Processed 1301 samples
# Processed 1401 samples
# Processed 1501 samples
# Processed 1601 samples
# Processed 1701 samples
# Processed 1801 samples
# Processed 1901 samples
# Processed 2001 samples
# Processed 2101 samples
# Processed 2201 samples
# Processed 2301 samples
# Processed 2401 samples
# Processed 2501 samples
# Processed 2601 samples
# Processed 2701 samples
# Processed 2801 samples
# Processed 2901 samples
# Processed 3001 samples
# Processed 3101 samples
# Processed 3201 samples
# Processed 3301 samples
# Processed 3401 samples
# Processed 3501 samples
# Processed 3601 samples
# Processed 3701 samples
# Processed 3801 samples
# Processed 3901 samples
# Processed 4001 samples
# Processed 4101 samples
# Processed 4201 samples
# Processed 4301 samples
# Processed 4401 samples
# Processed 4501 samples
# Processed 4601 samples
# Processed 4701 samples
# Processed 4801 samples
# Processed 4901 samples
# Processed 5001 samples
# Processed 5101 samples
# Processed 5201 samples
# Processed 5301 samples
# Processed 5401 samples
# Processed 5501 samples
# Processed 5601 samples
# Processed 5701 samples
# Processed 5801 samples
# Processed 5901 samples
# Processed 6001 samples
# Processed 6101 samples
# Processed 6201 samples
# Processed 6301 samples
# Processed 6401 samples
# Processed 6501 samples
# Processed 6601 samples
# Processed 6701 samples
# Processed 6801 samples
# Processed 6901 samples
# Processed 7001 samples
# Processed 7101 samples
# Processed 7201 samples
# Processed 7301 samples
# Processed 7401 samples
# Processed 7501 samples
# Processed 7601 samples
# Processed 7701 samples
# Processed 7801 samples
# Processed 7901 samples
# Processed 8001 samples
# Processed 8101 samples
# Processed 8201 samples
# Processed 8301 samples
# Processed 8401 samples
# Processed 8501 samples
# Processed 8601 samples
# Processed 8701 samples
# Processed 8801 samples
# Processed 8901 samples
# Processed 9001 samples
# Processed 9101 samples
# Processed 9201 samples
# Processed 9301 samples
# Processed 9401 samples
# Processed 9501 samples
# Processed 9601 samples
# Processed 9701 samples
# Processed 9801 samples
# Processed 9901 samples
# Accuracy on the first 100 samples: 0.3352

# %% [markdown]
# # Two step

# %%
import ollama
from sklearn.metrics import accuracy_score
def chat_with_context(history):
    response = ollama.chat(model='llama3', messages=history)
    return response['message']['content']
chat_history = []

num_samples = 5
# Updated Task Description for Restaurant Type Prediction
task_description = "We need to predict the type restaurant based on its name and one customer review. The categories are 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'."

generate_samples_request = (
    f"As an advanced language model you should create {num_samples} samples for the task outlined below.\n"
    "Generate samples that are likely to be correctly classified into one of the specified categories and samples that might be misclassified according to the task instructions.\n\n"
    f"### Task Description:\n{task_description}\n\n"
    "### Requirements for Samples:\n"
    "1. Each sample must present a unique and intricate challenge.\n"
    "2. The complexity of the samples should be such that simply applying the given task instruction would likely lead to incorrect or incomplete results for some samples.\n"
    "3. The samples should cover a diverse range of scenarios within the scope of the task, avoiding repetition and predictability.\n"
    "4. Ensure that the samples, while challenging, remain realistic and pertinent to the task's context.\n"
    "Generate the samples keeping these requirements in mind.\n###"
)

chat_history.append({'role': 'user', 'content': task_description})
chat_history.append({'role': 'user', 'content': generate_samples_request})

samples_response = chat_with_context(chat_history)
chat_history.append({'role': 'assistant', 'content': samples_response})
print("Generated Samples:")
print(samples_response)

# Analyze Samples with Chain of Thought Request
analyze_samples_request = (
    f"Based on the provided samples: {samples_response}\n"
    "Please think step by step and derive general principles for classifying restaurants into the specified categories: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
    "Focus on creating broad, example-agnostic guidelines that can be applied universally to classify any restaurant based on its name and customer reviews. Conclude your analysis with clear, concise bullet points outlining:\n"
    "- The key indicators or characteristics that typically define each category.\n"
    "- Common pitfalls that might lead to misclassifications and strategies for avoiding these errors.\n"
    "- Criteria or rules under which circumstances each label should be predicted.\n"
    "These principles should help in accurately predicting the cuisine type of a restaurant without relying on specific examples."
)

chat_history.append({'role': 'user', 'content': analyze_samples_request})

# Retrieve and print the analysis from the language model
analysis_response = chat_with_context(chat_history)
chat_history.append({'role': 'assistant', 'content': analysis_response})
print("Analysis of Restaurant Classification Guidelines:")
print(analysis_response)

# Generate Optimized Prompt
generate_prompt_request = (
    f"Based on the following analysis: {analysis_response}\nGenerate an optimized prompt for predicting "
    "the type of restaurant.\n\n"
    "### Requirements for Optimized Prompt:\n"
    "1. The prompt must include a clear description of the task and the labels.\n"
    "2. It should provide a comprehensive criteria for classifying restaurants as one of the restaurant types: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese' based on the name and customer review.\b"
    "3. The prompt should help the model avoid common pitfalls and misclassifications identified during the analysis.\n"
    "4. Ensure the language is unambiguous and tailored to maximize the model's prediction accuracy.\n"
    "5. Encourage the model to think step by step.\n"
    "Respond with no other explanation but only the content of the prompt that is ready for the model to predict\n"
    "Prompt:"
)

chat_history.append({'role': 'user', 'content': generate_prompt_request})

optimized_prompt_response = chat_with_context(chat_history)
chat_history.append({'role': 'assistant', 'content': optimized_prompt_response})
print("Optimized Prompt:")
print(optimized_prompt_response)
# Out:
# Generated Samples:
# Here are 5 sample restaurant name and review combinations that cover a diverse range of scenarios:
#
# **Sample 1:**
# Restaurant Name: Saffron Kitchen
# Customer Review: "Loved the unique fusion of Indian and Mediterranean flavors! The lamb shawarma was to die for."
# Prediction Challenge: Will this restaurant be correctly classified as 'Mediterranean' or 'Asian Fusion', considering the mention of Indian flavors?
#
# **Sample 2:**
# Restaurant Name: Burger Barn
# Customer Review: "Best veggie burger I've ever had! The sweet potato fries were a game-changer too."
# Prediction Challenge: This classic-sounding name might lead one to predict an 'American (Traditional)' restaurant, but will the mention of sweet potato fries tip the scales towards 'Canadian (New)' or something else?
#
# **Sample 3:**
# Restaurant Name: Tokyo Tacos
# Customer Review: "Craving authentic Japanese-Mexican fusion? Look no further! Their spicy tuna tacos are addictive."
# Prediction Challenge: With a name like Tokyo Tacos, one might expect a straightforward 'Japanese' classification. But will the mention of Mexican fusion and spicy tuna tacos lead to an alternative classification, such as 'Asian Fusion' or 'Thai'?
#
# **Sample 4:**
# Restaurant Name: La Bella Vita
# Customer Review: "This cozy Italian restaurant served the best homemade pasta I've ever had. The tiramisu was heavenly too!"
# Prediction Challenge: Will this seemingly traditional Italian name and review lead to a correct classification as 'Italian', or might the mention of homemade pasta and tiramisu hint at an alternative, such as 'Mediterranean'?
#
# **Sample 5:**
# Restaurant Name: Fusion Station
# Customer Review: "This innovative spot combines flavors from China, Japan, Korea, and Vietnam. The kimchi fried rice was a highlight!"
# Prediction Challenge: With a name like Fusion Station, one might expect an 'Asian Fusion' classification. But will the mention of specific countries and dishes (e.g., China, Japan, Korea, and Vietnam) lead to a more nuanced classification, such as 'Chinese', 'Japanese', or something else entirely?
#
# These samples aim to cover a range of challenges, from naming conventions to linguistic cues, to keep you on your toes while predicting the type restaurant!
# Analysis of Restaurant Classification Guidelines:
# After analyzing the provided samples, I've derived general principles for classifying restaurants into the specified categories. Here are the key findings:
#
# **Key Indicators/Characteristics:**
#
# 1. **'American (Traditional)':**
# 	* Name often includes "Barn", "Diner", or "Inn".
# 	* Review mentions classic American dishes like burgers, fries, and milkshakes.
# 	* May feature nostalgic or retro themes.
# 2. **'American (New)':**
# 	* Name might include "Fusion" or "Modern" to indicate a blend of cuisines.
# 	* Reviews highlight innovative twists on traditional American fare, such as gourmet burgers or creative sandwiches.
# 	* Emphasizes freshness, locally sourced ingredients, and unique presentation.
# 3. **'Mexican':**
# 	* Name typically includes "Tacos", "Mesa", "Rancho", or "Fiesta".
# 	* Reviews mention popular Mexican dishes like tacos, burritos, or enchiladas.
# 	* Often features vibrant, colorful themes and decorations inspired by Latin American culture.
# 4. **'Chinese':**
# 	* Name often includes "Wok", "Chow Mein", "Mandarin", or "Peking".
# 	* Reviews highlight traditional Chinese dishes like wonton soup, lo mein, or Kung Pao chicken.
# 	* May feature ornate decorations, pagodas, or other Asian-inspired elements.
# 5. **'Mediterranean':**
# 	* Name might include "Olive", "Grape", "Feta", or "Bazaar".
# 	* Reviews emphasize Mediterranean cuisine's focus on fresh vegetables, herbs, and seafood.
# 	* Often features warm, inviting colors and decorations inspired by the region's cultures (e.g., Greek, Turkish).
# 6. **'Italian':**
# 	* Name typically includes "Pizzeria", "Trattoria", or "Café" to indicate Italian heritage.
# 	* Reviews highlight traditional Italian dishes like pasta, pizza, or risotto.
# 	* May feature rustic, vintage-inspired decorations and a cozy atmosphere.
# 7. **'Thai':**
# 	* Name often includes "Thai", "Siam", or "Bangkok".
# 	* Reviews mention popular Thai dishes like pad thai, green curry, or tom yum soup.
# 	* Frequently features bold, colorful decorations inspired by Thai culture (e.g., temples, elephants).
# 8. **'Asian Fusion':**
# 	* Name might include "Fusion", "Mashup", or "East Meets West".
# 	* Reviews highlight innovative blends of Asian cuisines, such as Korean-Mexican fusion.
# 	* Often features modern, sleek decorations and a focus on unique flavor combinations.
# 9. **'Canadian (New)':**
# 	* Name typically includes "North", "Maple", or "Poutine" to indicate Canadian influences.
# 	* Reviews emphasize fresh, locally sourced ingredients and creative twists on classic Canadian dishes like poutine or Montreal-style bagels.
# 10. **'Japanese':**
# 	* Name often includes "Tokyo", "Sushi", or "Ramen".
# 	* Reviews highlight traditional Japanese cuisine's focus on sushi, ramen, or tempura.
# 	* May feature minimalist, modern decorations inspired by Japanese culture (e.g., cherry blossoms).
#
# **Common Pitfalls and Strategies:**
#
# 1. **Be wary of names that only include a cuisine's name without indicating the type of restaurant**: For example, "Thai Restaurant" might not be immediately classified as 'Thai'.
# 2. **Don't rely solely on specific dishes mentioned in reviews**: While dishes can be indicative, they may not be universally characteristic of the cuisine.
# 3. **Consider the tone and language used in reviews**: Reviews that emphasize freshness, local ingredients, or innovative twists might suggest a more modern or fusion-oriented approach.
#
# **Criteria/Rules for Prediction:**
#
# 1. **If the name includes words like "Tacos", "Mesa", or "Rancho", predict 'Mexican'.
# 2. **If the name features "Wok" or "Chow Mein", predict 'Chinese'.
# 3. **If the name mentions "Pizzeria", "Trattoria", or "Café" and reviews highlight pasta, pizza, or risotto, predict 'Italian'.
# 4. **If the name includes "Fusion", "Mashup", or "East Meets West", predict 'Asian Fusion' or a related cuisine (e.g., Korean-Mexican).
# 5. **If the name features "North", "Maple", or "Poutine" and reviews emphasize locally sourced ingredients, predict 'Canadian (New)'.
# 6. **If the name includes "Tokyo", "Sushi", or "Ramen" and reviews highlight traditional Japanese cuisine, predict 'Japanese'.
#
# By considering these key indicators, common pitfalls, and criteria, you can develop a systematic approach to predicting the type of restaurant based on its name and customer reviews.
# Optimized Prompt:
# Predict the type of restaurant based on its name and customer reviews. Given a restaurant name and review, classify it into one of the following categories:
#
# * 'American (Traditional)'
# * 'American (New)'
# * 'Mexican'
# * 'Chinese'
# * 'Mediterranean'
# * 'Italian'
# * 'Thai'
# * 'Asian Fusion'
# * 'Canadian (New)'
# * 'Japanese'
#
# Consider the following criteria to make your prediction:
#
# 1. If the name includes words like "Tacos", "Mesa", or "Rancho", predict 'Mexican'.
# 2. If the name features "Wok" or "Chow Mein", predict 'Chinese'.
# 3. If the name mentions "Pizzeria", "Trattoria", or "Café" and reviews highlight pasta, pizza, or risotto, predict 'Italian'.
# 4. If the name includes "Fusion", "Mashup", or "East Meets West", predict 'Asian Fusion' or a related cuisine (e.g., Korean-Mexican).
# 5. If the name features "North", "Maple", or "Poutine" and reviews emphasize locally sourced ingredients, predict 'Canadian (New)'.
# 6. If the name includes "Tokyo", "Sushi", or "Ramen" and reviews highlight traditional Japanese cuisine, predict 'Japanese'.
#
# Be cautious of names that only include a cuisine's name without indicating the type of restaurant. Avoid relying solely on specific dishes mentioned in reviews. Instead, consider the tone and language used in reviews to inform your prediction.
#
# Predict the type of restaurant based on its name and customer review: [Insert Name] - [Insert Review].

# %%
# Function to predict the cuisine type of a given restaurant
def get_prediction(restaurant_name, customer_review):

    init_prompt = (
        "Follow the guidelines of the prompt:\n"
        f"{optimized_prompt_response}\n\n"
        f"Restaurant Name: {restaurant_name}\n"
        f"Customer Review: {customer_review}\n"
        "### Initial Analysis:\n"
        "Provide your detailed analysis and suggest a category based on the content of the restaurant name and customer review."
    )
    init_response = ollama.generate(model='llama3', prompt=init_prompt)
    detailed_analysis = init_response['response'].strip()
    final_prompt = (
        "Based on the detailed analysis, respond with only the most matched category name from one of the following: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'\n"
        f"{detailed_analysis}\n"
        "### Requirements:\n"
        "1. Respond with only the restaurant type: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'.\n"
        "2. Do not provide any additional text or explanation.\n"
        "Respond with only the category name:"
    )
    response = ollama.generate(model='llama3', prompt=final_prompt)
    prediction = response['response'].strip().lower().replace("**", "").replace("'", "").replace('"', '')
    # if prediction not in ['American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese']:
    #     prediction = get_prediction(restaurant_name, customer_review)
    return prediction

predictions = []

for i, row in df_train.iterrows():
    if i == 10000:
        break
    
    restaurant_name = row['name']
    customer_review = row['review']
    prediction = get_prediction(restaurant_name, customer_review)
    predictions.append(prediction)
    if i % 1000 == 0:
        print(f"Processed {i+1} samples")
        acc = accuracy_score(df_train['label'][:len(predictions)], predictions)
        print(f"Accuracy after {i+1} samples: {acc}")
    # print(f"Predicted Restaurant Type: {prediction}\n")
    # print(f"Actual Restaurant Type: {row['label']}\n")

accuracy = accuracy_score(df_train['label'][:len(predictions)], predictions)
print(f"Accuracy: {accuracy}")
# Out:
# Processed 1 samples
# Accuracy after 1 samples: 1.0
# Processed 1001 samples
# Accuracy after 1001 samples: 0.7202797202797203
# Processed 2001 samples
# Accuracy after 2001 samples: 0.7211394302848576
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 36
#      34 restaurant_name = row['name']
#      35 customer_review = row['review']
# ---> 36 prediction = get_prediction(restaurant_name, customer_review)
#      37 predictions.append(prediction)
#      38 if i % 1000 == 0:
#
# Cell In[71], line 22, in get_prediction(restaurant_name, customer_review)
#      13 detailed_analysis = init_response['response'].strip()
#      14 final_prompt = (
#      15     "Based on the detailed analysis, respond with only the most matched category name from one of the following: 'American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese'\n"
#      16     f"{detailed_analysis}\n"
#    (...)
#      20     "Respond with only the category name:"
#      21 )
# ---> 22 response = ollama.generate(model='llama3', prompt=final_prompt)
#      23 prediction = response['response'].strip().lower().replace("**", "").replace("'", "").replace('"', '')
#      24 # if prediction not in ['American (Traditional)', 'American (New)', 'Mexican', 'Chinese', 'Mediterranean', 'Italian', 'Thai', 'Asian Fusion', 'Canadian (New)', 'Japanese']:
#      25 #     prediction = get_prediction(restaurant_name, customer_review)
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ollama\_client.py:126, in Client.generate(self, model, prompt, system, template, context, stream, raw, format, images, options, keep_alive)
#     123 if not model:
#     124   raise RequestError('must provide a model')
# --> 126 return self._request_stream(
#     127   'POST',
#     128   '/api/generate',
#     129   json={
#     130     'model': model,
#     131     'prompt': prompt,
#     132     'system': system,
#     133     'template': template,
#     134     'context': context or [],
#     135     'stream': stream,
#     136     'raw': raw,
#     137     'images': [_encode_image(image) for image in images or []],
#     138     'format': format,
#     139     'options': options or {},
#     140     'keep_alive': keep_alive,
#     141   },
#     142   stream=stream,
#     143 )
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ollama\_client.py:97, in Client._request_stream(self, stream, *args, **kwargs)
#      91 def _request_stream(
#      92   self,
#      93   *args,
#      94   stream: bool = False,
#      95   **kwargs,
#      96 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 97   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ollama\_client.py:68, in Client._request(self, method, url, **kwargs)
#      67 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 68   response = self._client.request(method, url, **kwargs)
#      70   try:
#      71     response.raise_for_status()
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\solow\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
